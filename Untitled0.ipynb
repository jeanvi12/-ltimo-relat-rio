# %% [markdown]
# <a href="https://colab.research.google.com/github/jeanvi12/-ltimo-relat-rio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate scipy safetensors xforms

# %%
import os
os.environ["HF_TOKEN"] = "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"
import torch
from diffusers import StableDiffusionPipeline, DPMSolverMultistepScheduler

model_id = "stabilityai/stable-diffusion-2-1"

# Use the DPMSolverMultistepScheduler (DPM-Solver++) scheduler here instead
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe = pipe.to("cuda")

prompt = "a photo of a funny picture of poor brain"
image = pipe(prompt).images[0]
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
plt.imshow(image)
plt.show()
